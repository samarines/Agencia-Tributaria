# %%
import pandas as pd

tabla = pd.read_html('https://sede.agenciatributaria.gob.es/AEAT/Contenidos_Comunes/La_Agencia_Tributaria/Estadisticas/Publicaciones/sites/irpfmunicipios/2020/jrubik5492ca0dcc79cfe7c0ac396f2b1e0e745c238bd7.html')

# %%
type(tabla)
# Out:
# list

# %%
df = tabla[0].set_index('Unnamed: 0')
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, RENDIMIENTOS DEL TRABAJO (neto reducido) to RESULTADO DE LA DECLARACIÓN A DEVOLVER
# Data columns (total 3 columns):
# Número     58 non-null object
# Importe    58 non-null object
# Media      58 non-null object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
df.reset_index(inplace=True)
df.rename({'Unnamed: 0': 'Concepto'}, axis=1, inplace=True)
df
# Out:
#                                              Concepto     Número     Importe  \
# 0            RENDIMIENTOS DEL TRABAJO (neto reducido)  1.429.247  22.937.459
# 1                                   Ingresos íntegros  1.679.713  31.619.088
# 2   Contribuciones empresariales a planes de pensi...     26.840      40.536
# 3                                   Gastos deducibles  1.148.992   1.612.684
# 4          Cotizaciones a la Seguridad Social u otras  1.142.180   1.587.194
# 5   Cuotas satisfechas a sindicatos y colegios pro...    148.154      24.761
# 6                             Rendimiento neto previo  1.680.660  29.977.526
# 7                                    Rendimiento neto  1.638.588  26.566.514
# 8                             Reducciones del trabajo  1.679.038   7.109.471
# 9                    Reducciones del trabajo: general  1.679.029   6.946.843
# 10  Reducción adicional para trabajadores activos ...     23.981      89.264
# ...
